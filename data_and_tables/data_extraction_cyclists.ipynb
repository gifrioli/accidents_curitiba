# %% [markdown]
# # Data Extraction
#
# My data was obtained through Brazil's Access to Information Law. The documents were submitted in PDF format, so I decided to use the Natural PDF library, created by Professor Jonathan Soma, to extract the numbers. Library documentation is available at: https://jsoma.github.io/natural-pdf/

# %%
#Extracting only data on accidents involving cyclists in 2020

# %%
from natural_pdf import PDF

pdf_path = 'atropelamentos_curitiba/ATROPELAMENTO_CICLISTA_2020.pdf'
pdf = PDF(pdf_path)

# %%
all_dfs = []

for page_number in range(len(pdf.pages)):
    page = pdf.pages[page_number]
    
    table = page.extract_table(method="pdfplumber")
    
    if table:
        
        df = table.to_df()
        all_dfs.append(df)
    else:
        print(f"No tables found on page {page_number + 1}")

import pandas as pd

df_completo = pd.concat(all_dfs, ignore_index=True)

print(df_completo)
# Out:
#             DATA   HORA LINHA EMPRESA PREFIXO TIPO DE ACIDENTE  \
# 0   05/01/202\n0  21:53   603     007   HE717    ATROPELAMENTO
# 1   09/01/202\n0  22:40   304     005   DL303    ATROPELAMENTO
# 2   16/01/202\n0  18:23   500     011   GE718    ATROPELAMENTO
# 3   30/01/202\n0  20:20   505     006   EL305    ATROPELAMENTO
# 4   05/02/202\n0  13:58   619     007   HI017    ATROPELAMENTO
# 5   06/02/202\n0  17:18   680     007   HA028    ATROPELAMENTO
# 6   11/02/202\n0  13:56   541     011   GC014    ATROPELAMENTO
# 7   15/02/202\n0  18:41   303     009   LE705    ATROPELAMENTO
# 8   28/02/202\n0  09:39   700     007   HL318    ATROPELAMENTO
# 9   04/03/202\n0  16:38   471     006   EA204    ATROPELAMENTO
# 10  06/03/202\n0  21:32   505     006   EL313    ATROPELAMENTO
# 11  06/03/202\n0  14:03   503     011   GE601    ATROPELAMENTO
# 12  10/03/202\n0  17:15   500     011   GE711    ATROPELAMENTO
# 13  26/04/202\n0  07:23   506     006   EL309    ATROPELAMENTO
# ...

# %%
csv_path = 'acidentes_ciclistas_2020.csv'

#Save in CSV
df_completo.to_csv(csv_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# # There are five different PDFs just for accidents involving cyclists (last five years), so I extracted them one by one

# %%
#Extracting accidents involving cyclists in 2021

# %%
pdf_path = 'atropelamentos_curitiba/ATROPELAMENTO_CICLISTA_2021.pdf'
pdf = PDF(pdf_path)

# %%
all_dfs = []

for page_number in range(len(pdf.pages)):
    page = pdf.pages[page_number]
    
    table = page.extract_table(method="pdfplumber")
    
    if table:
        
        df = table.to_df()
        all_dfs.append(df)
    else:
        print(f"No tables found on page {page_number + 1}")

import pandas as pd

df_completo = pd.concat(all_dfs, ignore_index=True)

print(df_completo)
# Out:
#             DATA   HORA LINHA EMPRESA PREFIXO TIPO DE ACIDENTE  \
# 0   07/01/202\n1  07:24   629     002   KA605    ATROPELAMENTO
# 1   22/01/202\n1  06:42   323     005   DA022    ATROPELAMENTO
# 2   06/02/202\n1  15:16   203     007   HE718    ATROPELAMENTO
# 3   15/02/202\n1  20:58   X20     007   HE728    ATROPELAMENTO
# 4   17/03/202\n1  06:45   550     011   GD348    ATROPELAMENTO
# 5   18/03/202\n1  13:41   500     011   GE716    ATROPELAMENTO
# 6   07/04/202\n1  07:36   684     007   HI609    ATROPELAMENTO
# 7   20/04/202\n1  16:59   602     007   HE614    ATROPELAMENTO
# 8   26/04/202\n1  07:15   505     006   EL317    ATROPELAMENTO
# 9   20/05/202\n1  12:11   550     007   HE727    ATROPELAMENTO
# 10  02/06/202\n1  13:33   684     007   HI604    ATROPELAMENTO
# 11  06/06/202\n1  00:40   040     011   GB611    ATROPELAMENTO
# 12  10/06/202\n1  10:13   550     011   GE710    ATROPELAMENTO
# 13  11/06/202\n1  17:53   523     006   EI008    ATROPELAMENTO
# ...

# %%
csv_path = 'acidentes_ciclistas_2021.csv'

#Save in CSV
df_completo.to_csv(csv_path, index=False, encoding='utf-8-sig')

# %%
#Extracting accidents involving cyclists in 2022

# %%
pdf_path = 'atropelamentos_curitiba/ATROPELAMENTO_CICLISTAS_2022.pdf'
pdf = PDF(pdf_path)

# %%
all_dfs = []

for page_number in range(len(pdf.pages)):
    page = pdf.pages[page_number]
    
    table = page.extract_table(method="pdfplumber")
    
    if table:
        
        df = table.to_df()
        all_dfs.append(df)
    else:
        print(f"No tables found on page {page_number + 1}")

import pandas as pd

df_completo = pd.concat(all_dfs, ignore_index=True)

print(df_completo)
# Out:
#             DATA   HORA LINHA EMPRESA PREFIXO TIPO DE ACIDENTE  \
# 0   24/01/202\n2  09:36   603     011   GE703    ATROPELAMENTO
# 1   25/02/202\n2  16:10   X39     004   CB697    ATROPELAMENTO
# 2   02/03/202\n2  18:55   302     005   DE707    ATROPELAMENTO
# 3   09/03/202\n2  12:19   502     011   GR035    ATROPELAMENTO
# 4   10/03/202\n2  15:00   303     005   DE703    ATROPELAMENTO
# 5   17/03/202\n2  20:31   603     007   HE722    ATROPELAMENTO
# 6   26/04/202\n2  18:31   550     011   GE715    ATROPELAMENTO
# 7   27/04/202\n2  12:02   552     011   GC010    ATROPELAMENTO
# 8   19/05/202\n2  18:10   706     008   JC302    ATROPELAMENTO
# 9   25/05/202\n2  07:24   625     011   GI036    ATROPELAMENTO
# 10  14/06/202\n2  13:36   550     007   HE719    ATROPELAMENTO
# 11  22/06/202\n2  21:50   303     005   DE713    ATROPELAMENTO
# 12  04/07/202\n2  18:50   380     004   CC194    ATROPELAMENTO
# 13  26/07/202\n2  18:32   X20     007   HE602    ATROPELAMENTO
# ...

# %%
csv_path = 'acidentes_ciclistas_2022.csv'

#Save in CSV
df_completo.to_csv(csv_path, index=False, encoding='utf-8-sig')

# %%
#Extracting accidents involving cyclists in 2023

# %%
pdf_path = 'atropelamentos_curitiba/ATROPELAMENTO_CICLISTA_2023.pdf'
pdf = PDF(pdf_path)

# %%
all_dfs = []

for page_number in range(len(pdf.pages)):
    page = pdf.pages[page_number]
    
    table = page.extract_table(method="pdfplumber")
    
    if table:
        
        df = table.to_df()
        all_dfs.append(df)
    else:
        print(f"No tables found on page {page_number + 1}")

import pandas as pd

df_completo = pd.concat(all_dfs, ignore_index=True)

print(df_completo)
# Out:
#             DATA   HORA LINHA EMPRESA PREFIXO TIPO DE ACIDENTE  \
# 0   23/01/202\n3  09:41   508     011   GL329    ATROPELAMENTO
# 1   23/01/202\n3  18:21   531     006   EA023    ATROPELAMENTO
# 2   17/02/202\n3  19:52   633     011   GC018    ATROPELAMENTO
# 3   26/02/202\n3  11:30   684     007   HI043    ATROPELAMENTO
# 4   05/03/202\n3  20:27   603     007   HE724    ATROPELAMENTO
# 5   06/03/202\n3  19:09   550     007   HE704    ATROPELAMENTO
# 6   13/03/202\n3  18:51   203     007   HE717    ATROPELAMENTO
# 7   28/03/202\n3  17:10   303     008   JE709    ATROPELAMENTO
# 8   06/04/202\n3  20:30   060     007   HB601    ATROPELAMENTO
# 9   12/04/202\n3  05:55   603     007   HE728    ATROPELAMENTO
# 10  18/04/202\n3  18:07   603     007   HE700    ATROPELAMENTO
# 11  18/04/202\n3  19:01   505     006   EL330    ATROPELAMENTO
# 12  19/04/202\n3  16:32   338     005   DC297    ATROPELAMENTO
# 13  07/05/202\n3  19:40   203     003   BE727    ATROPELAMENTO
# ...

# %%
csv_path = 'acidentes_ciclistas_2023.csv'

#Save in CSV
df_completo.to_csv(csv_path, index=False, encoding='utf-8-sig')

# %%
#Extracting accidents involving cyclists in 2024

# %%
pdf_path = 'atropelamentos_curitiba/ATROPELAMENTO_CICLISTA_2024.pdf'
pdf = PDF(pdf_path)

# %%
all_dfs = []

for page_number in range(len(pdf.pages)):
    page = pdf.pages[page_number]
    
    table = page.extract_table(method="pdfplumber")
    
    if table:
        
        df = table.to_df()
        all_dfs.append(df)
    else:
        print(f"No tables found on page {page_number + 1}")

import pandas as pd

df_completo = pd.concat(all_dfs, ignore_index=True)

print(df_completo)
# Out:
#             DATA   HORA LINHA EMPRESA PREFIXO TIPO DE ACIDENTE  \
# 0   17/01/202\n4  16:20   550     007   HE701    ATROPELAMENTO
# 1   18/01/202\n4  07:20   550     007   HE709    ATROPELAMENTO
# 2   09/02/202\n4  15:54   603     007   HE703    ATROPELAMENTO
# 3   21/02/202\n4  07:41   550     007   HE719    ATROPELAMENTO
# 4   24/02/202\n4  16:40   203     003   BE725    ATROPELAMENTO
# 5   24/02/202\n4  10:45   307     004   CL302    ATROPELAMENTO
# 6   25/02/202\n4  10:56   545     002   KC001    ATROPELAMENTO
# 7   04/03/202\n4  08:19   350     007   HD250    ATROPELAMENTO
# 8   09/03/202\n4  15:30   505     006   EL325    ATROPELAMENTO
# 9   09/03/202\n4  09:30   680     007   HI033    ATROPELAMENTO
# 10  14/03/202\n4  12:17   203     007   HE717    ATROPELAMENTO
# 11  27/03/202\n4  10:10   500     011   GE719    ATROPELAMENTO
# 12  28/03/202\n4  18:52   302     005   DE698    ATROPELAMENTO
# 13  09/04/202\n4  18:10   250     003   BE717    ATROPELAMENTO
# ...

# %%
csv_path = 'acidentes_ciclistas_2024.csv'

#Save in CSV
df_completo.to_csv(csv_path, index=False, encoding='utf-8-sig')

# %%
#Extracting accidents involving cyclists in 2025

# %%
pdf_path = 'atropelamentos_curitiba/ATROPELAMENTO_CICLISTA_2025.pdf'
pdf = PDF(pdf_path)

# %%
all_dfs = []

for page_number in range(len(pdf.pages)):
    page = pdf.pages[page_number]
    
    table = page.extract_table(method="pdfplumber")
    
    if table:
        
        df = table.to_df()
        all_dfs.append(df)
    else:
        print(f"No tables found on page {page_number + 1}")

import pandas as pd

df_completo = pd.concat(all_dfs, ignore_index=True)

print(df_completo)
# Out:
#             DATA   HORA LINHA EMPRESA PREFIXO TIPO DE ACIDENTE  \
# 0   10/01/202\n5  09:28   515     006   EI004    ATROPELAMENTO
# 1   14/01/202\n5  13:08   653     007   HA022    ATROPELAMENTO
# 2   16/01/202\n5  17:50   623     007   HI047    ATROPELAMENTO
# 3   21/01/202\n5  17:46   274     003   BI861    ATROPELAMENTO
# 4   23/01/202\n5  16:03   707     007   HL496    ATROPELAMENTO
# 5   11/02/202\n5  09:56   707     007   HL495    ATROPELAMENTO
# 6   18/02/202\n5  23:23   303     011   GE709    ATROPELAMENTO
# 7   24/02/202\n5  14:29   685     007   HI614    ATROPELAMENTO
# 8   01/03/202\n5  12:44   700     003   BL358    ATROPELAMENTO
# 9   07/03/202\n5  19:41   X37     007   HI600    ATROPELAMENTO
# 10  14/03/202\n5  23:26   350     011   GE604    ATROPELAMENTO
# 11  19/03/202\n5  17:06   023     007   HL600    ATROPELAMENTO
# 12  25/03/202\n5  16:19   550     007   HE718    ATROPELAMENTO
# 13  02/04/202\n5  08:26   350     011   GE611    ATROPELAMENTO
# ...

# %%
csv_path = 'acidentes_ciclistas_2025.csv'

#Save in CSV
df_completo.to_csv(csv_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# # I saved the tables into one and added the year.

# %%
years = [2020, 2021, 2022, 2023, 2024,2025]
dfs = []

for year in years:
    archive = f'acidentes_ciclistas_{year}.csv'
    df = pd.read_csv(archive)
    df['Ano'] = year
    dfs.append(df)

df_combine = pd.concat(dfs, ignore_index=True)
df_combine.to_csv('acidentes_ciclistas_todos_anos.csv', index=False, encoding='utf-8-sig')
